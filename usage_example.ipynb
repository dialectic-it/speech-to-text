# %%
#Для решения задачи автоматического распознавания русской речи:
#А) Статья: https://habr.com/ru/company/ods/blog/692246/;
#Б) Открытый репо: https://github.com/openai/whisper;
#В) туториал: https://github.com/openai/whisper/blob/main/notebooks/Multilingual_ASR.ipynb
#Г) Решение универсально, работает для любого языка, см. документацию в А).

import warnings
warnings.simplefilter('ignore')
                        
import torch
import whisper
from whisper.utils import format_timestamp

DEVICE = "cuda:0" if torch.cuda.is_available() else "cpu"
model = whisper.load_model("medium") # 1 раз скачать - дальше можно пользоваться без интернета
options = dict(language='ru', beam_size=5, best_of=5)
transcribe_options = dict(task="transcribe", **options)

# %% [markdown]
# ## ex1

# %%
dict_pred = model.transcribe('./data_ru/ex2.mp3', **transcribe_options)
#print(dict_pred.keys()) # dict_keys(['text', 'segments', 'language'])
dict_pred['text']
# Out:
# ' Внутренний аудит – это форма контроля деятельности организации изнутри. Процедура помогает руководству проверять финансовое состояние бизнеса и достоверность отчётности.'

# %%
dict_pred = model.transcribe('./data_ru/ex2.mp3', **transcribe_options)

for segment in dict_pred['segments']:
    print(f"[{format_timestamp(segment['start'])} --> {format_timestamp(segment['end'])}] {segment['text']}")
# Out:
# [00:00.000 --> 00:07.000]  Внутренний аудит – это форма контроля деятельности организации изнутри.
# [00:07.000 --> 00:35.000]  Процедура помогает руководству проверять финансовое состояние бизнеса и достоверность отчётности.

# %% [markdown]
# ## ex2

# %%
# %%time
model.transcribe('./data_ru/Tovji10XSao.mp3', **transcribe_options)["text"]
# https://www.youtube.com/watch?v=Tovji10XSao
# Out:
# CPU times: total: 2min 3s
# Wall time: 1min 51s
# ' Про плюсы одной из самых дорогих услуг в стоматологии вроде бы все понятно. Давайте разбираться с отрицательной стороной этой процедуры. Приветствуем! С вами экспертный журнал о стоматологии StartSmile.ru. И сейчас будем ругать имплантацию как только возможно. Не все ведь о голливудских улыбках рассказывать. Начнем с того, что операцию по имплантации зубов невозможно провести людям с абсолютными или временными противопоказаниями. И если некоторые временные ограничения, такие как беременность, удастся просто переждать, то на устранение других стоматологических проблем потребуется не только время, но и деньги. Карие с соседних зубов, плохая гигиена ротовой полости, воспаление десен, проблемы с прикусом и другие причины – все это является относительным противопоказанием к имплантации. Пока не избавитесь от подобного списка, составленного на первой консультации у имплантолога, о новых зубах придется забыть. Помимо временных, есть список абсолютных противопоказаний, при которых имплантация невозможна совсем. Болезни крови, психические заболевания, онкологические болезни и огромный список других проблем, которые мы перечислим в описании к этому ролику, чтобы вам было удобнее ознакомиться. В этих случаях стоит лишь ждать, надеяться и верить, что стоматология не будет стоять на месте и когда-нибудь станет доступна для всех людей. Но ждать, видимо, придется долго, почти как следующего минуса имплантации. Если не брать во внимание одномоментные методики установки импланта, которые позволяют сразу же поставить временную коронку, то нам определенно стоит вспомнить о длительности всего этапа имплантации зубов. Первое, с чем вы можете столкнуться, это устранение временных противопоказаний. Наращивание костной ткани, например, может занять от 3 до 6 месяцев, а исправление прикуса может длиться от 1 до 3 лет. После устранения подобных проблем вам установят имплант. А для установки коронки на имплант придется дождаться периода приживления последнего. Он может занять от 2 до 4 месяцев, в зависимости от места установки. И, наконец, самое неприятное, что может вас ожидать после имплантации зубов – отторжение импланта. На этом остановимся поподробнее. Если отторжение произошло в первые два года, то, скорее всего, к этому привела ошибка врача. И тут вам может помочь гарантия, которую хорошие клиники стараются выдавать своим пациентам, дабы обезопасить от подобных последствий. Если отторжение произошло позже, то винить, скорее всего, стоит только себя – за плохую гигиену полости рта и нерегулярное посещение стоматолога. Да, за новыми искусственными зубами необходимо следить как за своими. Ужасно все выглядит, не правда ли? Но для честности давайте скажем, что отторжение импланта возникает лишь в 3% случаев. А срок подготовки к имплантации можно сократить или вовсе избежать быстрым обращением к стоматологу после потери зуба. Следующий минус имплантации также очень сильно зависит от конкретного случая – стоимость. Для получения идеального результата в короткие сроки придется расстаться с приличной суммой денег. Например, стоимость одного импланта с керамической коронкой обойдется вам от 40 тысяч рублей. Дополнительные затраты могут возникнуть из-за сложности вашего случая и наличия временных противопоказаний. Сэкономить можно как на классе клиники, так и на материале импланта и коронки. Но сразу в голове всплывают те самые 3%, о которых мы говорили ранее. Найти баланс между надежностью и хорошей стоимостью порой очень непросто. Тут можем лишь порекомендовать перейти по ссылке в описании на наш портал startsmile.ru. Там мы специально собрали список клиник из разных ценовых категорий, в которые вы можете записаться на прием через специальную форму на сайте. Или звоните по телефонам, которые вы сейчас видите на экране, и мы поможем вам подобрать идеального для вас стоматолога. Пишите в комментариях про ваш опыт имплантации зубов, про все положительные и отрицательные моменты, с которыми вам пришлось столкнуться. А если вы совсем разочаровались, то посм ...

# %%
dict_pred = model.transcribe('./data_ru/Tovji10XSao.mp3', **transcribe_options)

for segment in dict_pred['segments']:
    start_time = format_timestamp(segment['start'], always_include_hours=True).split('.')[0]
    end_time = format_timestamp(segment['end'], always_include_hours=True).split('.')[0]
    text = f"[{start_time}-{end_time}] {segment['text']}"
    print(text)
# Out:
# [00:00:00-00:00:05]  Про плюсы одной из самых дорогих услуг в стоматологии вроде бы все понятно.
# [00:00:05-00:00:09]  Давайте разбираться с отрицательной стороной этой процедуры.
# [00:00:15-00:00:20]  Приветствуем! С вами экспертный журнал о стоматологии StartSmile.ru.
# [00:00:20-00:00:24]  И сейчас будем ругать имплантацию как только возможно.
# [00:00:24-00:00:31]  Не все ведь о голливудских улыбках рассказывать.
# [00:00:31-00:00:39]  Начнем с того, что операцию по имплантации зубов невозможно провести людям с абсолютными или временными противопоказаниями.
# [00:00:39-00:00:45]  И если некоторые временные ограничения, такие как беременность, удастся просто переждать,
# [00:00:45-00:00:51]  то на устранение других стоматологических проблем потребуется не только время, но и деньги.
# [00:00:51-00:01:02]  Карие с соседних зубов, плохая гигиена ротовой полости, воспаление десен, проблемы с прикусом и другие причины – все это является относительным противопоказанием к имплантации.
# [00:01:02-00:01:10]  Пока не избавитесь от подобного списка, составленного на первой консультации у имплантолога, о новых зубах придется забыть.
# [00:01:10-00:01:17]  Помимо временных, есть список абсолютных противопоказаний, при которых имплантация невозможна совсем.
# [00:01:17-00:01:29]  Болезни крови, психические заболевания, онкологические болезни и огромный список других проблем, которые мы перечислим в описании к этому ролику, чтобы вам было удобнее ознакомиться.
# [00:01:29-00:01:38]  В этих случаях стоит лишь ждать, надеяться и верить, что стоматология не будет стоять на месте и когда-нибудь станет доступна для всех людей.
# [00:01:38-00:01:47]  Но ждать, видимо, придется долго, почти как следующего минуса имплантации.
# [00:01:47-00:01:54]  Если не брать во внимание одномоментные методики установки импланта, которые позволяют сразу же поставить временную коронку,
# [00:01:54-00:02:00]  то нам определенно стоит вспомнить о длительности всего этапа имплантации зубов.
# [00:02:00-00:02:14]  Первое, с чем вы можете столкнуться, это устранение временных противопоказаний. Наращивание костной ткани, например, может занять от 3 до 6 месяцев, а исправление прикуса может длиться от 1 до 3 лет.
# [00:02:14-00:02:18]  После устранения подобных проблем вам установят имплант.
# [00:02:18-00:02:27]  А для установки коронки на имплант придется дождаться периода приживления последнего. Он может занять от 2 до 4 месяцев, в зависимости от места установки.
# [00:02:27-00:02:40]  И, наконец, самое неприятное, что может вас ожидать после имплантации зубов – отторжение импланта. На этом остановимся поподробнее.
# [00:02:40-00:02:46]  Если отторжение произошло в первые два года, то, скорее всего, к этому привела ошибка врача.
# [00:02:46-00:02:54]  И тут вам может помочь гарантия, которую хорошие клиники стараются выдавать своим пациентам, дабы обезопасить от подобных последствий.
# [00:02:54-00:03:03]  Если отторжение произошло позже, то винить, скорее всего, стоит только себя – за плохую гигиену полости рта и нерегулярное посещение стоматолога.
# [00:03:03-00:03:10]  Да, за новыми искусственными зубами необходимо следить как за своими. Ужасно все выглядит, не правда ли?
# [00:03:10-00:03:16]  Но для честности давайте скажем, что отторжение импланта возникает лишь в 3% случаев.
# [00:03:16-00:03:24]  А срок подготовки к имплантации можно сократить или вовсе избежать быстрым обращением к стоматологу после потери зуба.
# [00:03:28-00:03:34]  Следующий минус имплантации также очень сильно зависит от конкретного случая – стоимость.
# [00:03:34-00:03:41]  Для получения идеального результата в короткие сроки придется расстаться с приличной суммой денег.
# [00:03:41-00:03:47]  Например, стоимость одного импланта с керамической коронкой обойдется вам от 40 тысяч рублей.
# [00:03:47-00:03:54]  Дополнительные затраты могут возникнуть из-за сложности вашего случая и наличия временных противопоказаний.
# [00:03:54-00:03:59]  Сэкономить можно как на классе клиники, так и на материале импланта и коронки.
# [00:03:59-00:04:04]  Но сразу в голове всплывают те самые 3%, о которых мы говорили ранее.
# [00:04:04-00:04:11]  Найти баланс между надежностью и хорошей стоимостью порой очень непросто.
# [00:04:11-00:04:17]  Тут можем лишь порекомендовать перейти по ссылке в описании на наш портал startsmile.ru.
# [00:04:17-00:04:21]  Там мы специально собрали список клиник из разных ценовых категорий,
# [00:04:21-00:04:26]  в которые вы можете записаться на прием через специальную форму на сайте.
# [00:04:26-00:04:30]  Или звоните по телефонам, которые вы сейчас видите на экране,
# [00:04:30-00:04:34]  и мы поможем вам подобрать идеального для вас стоматолога.
# [00:04:36-00:04:39]  Пишите в комментариях про ваш опыт имплантации зубов,
# [00:04:39-00:04:44]  про все положительные и отрицательные моменты, с которыми вам пришлось столкнуться.
# [00:04:44-00:04:50]  А если вы совсем разочаровались, то посмотрите наше видео про плюсы имплантации зубов.
# [00:04:50-00:05:00]  Подписывайтесь на наш канал и становитесь экспертами в стоматологии вместе с нами.

# %% [markdown]
# ## prod

# %%
import warnings
warnings.simplefilter('ignore')

import math
import time
import os
import shutil
import yaml
from pydub import AudioSegment

import torch
import whisper
from whisper.utils import format_timestamp
torch.cuda.empty_cache()

def create_folder(path):
    try:
        os.mkdir(path)
    except OSError as error: 
        pass
    
def delete_folder(path):
    try:
        shutil.rmtree(path)
    except FileNotFoundError as error: 
        pass

def stt_processing_1_audio(filepath, model, params, transcribe_options):
    name = filepath.split('/')[-1]
    file_format = name.split('.')[-1]
    resultpath1 = os.path.join(params['RESULTPATH'], '{}_net.txt'.format(name))
    resultpath2 = os.path.join(params['RESULTPATH'], '{}_net_ts.txt'.format(name))
    sound = AudioSegment.from_file(filepath)
    
    len_ms = len(sound)
    dt = 1000*params['PART_LEN']
    n_parts = math.ceil(len_ms/dt)
    temp_folder = './temp_folder/'
    create_folder(temp_folder)
    
    for i in range(n_parts):
        print('{}/{}'.format(i+1,n_parts))
        sound_part = sound[dt*i:dt*(i+1)]
        temp_filepath = os.path.join(temp_folder, 'part_{}.{}'.format(i,file_format))
        sound_part.export(temp_filepath, format=file_format)
        dict_pred = model.transcribe(temp_filepath, **transcribe_options)
        
        text = dict_pred["text"]
        if type(text)==list:
            text = text[0]
        with open(resultpath1, "a") as f1:
            f1.writelines(text+"\n======= {}:{}\n".format((i+1)*params['PART_LEN']//60,
                                                         (i+1)*params['PART_LEN']%60))  
        with open(resultpath2, "a") as f2:
            for segment in dict_pred['segments']:
                start_time = format_timestamp(segment['start']+i*params['PART_LEN'],
                                              always_include_hours=True).split('.')[0]
                end_time = format_timestamp(segment['end']+i*params['PART_LEN'],
                                            always_include_hours=True).split('.')[0]
                text = f"[{start_time}-{end_time}] {segment['text']}"
                f2.writelines(text+'\n')
    delete_folder(temp_folder)
    

if __name__ == "__main__":   
    with open("params.yml", "r") as stream:
        params = yaml.safe_load(stream)

    asr_model = whisper.load_model(name=params['MODEL_NAME'], device=params['DEVICE']) 
    options = dict(language=params['LANG'], beam_size=5, best_of=5)
    transcribe_options = dict(task="transcribe", **options)
    
    print('Обрабатываю файл', params['FILEPATH'])
    start_time = time.time()
    stt_processing_1_audio(params['FILEPATH'], asr_model, params, transcribe_options)
    dt = (time.time()-start_time)/60 # min
    print('Обработка завершена, обработка длилась {} минут'.format(round(dt,2)))
# Out:
# Обрабатываю файл ./data_ru/ex2.mp3
# 1/1
# Обработка завершена, обработка длилась 0.13 минут
